# %%
from pandas import read_csv
from numpy import nan
import seaborn as sls
import matplotlib as plt 
import numpy as np
import pandas as pd

# %%
features={0: 'Number of times pregnant',
1: 'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
2: 'Diastolic blood pressure (mm Hg)',
3:' Triceps skinfold thickness (mm)',
4:' 2-Hour serum insulin (mu U/ml)',
5:' Body mass index (weight in kg/(height in m)^2)',
6:'Diabetes pedigree function',
7: 'Age (years)',
8: 'Class variable (0 or 1)'}
file= read_csv('pima-indians-diabetes.csv',header=None)
print(file.describe())
# Out:
#                 0           1           2           3           4           5  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#                 6           7           8
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
print((file[[1,2,3,4,5]]==0).sum())

file[[1,2,3,4,5]] = file[[1,2,3,4,5]].replace(0, nan)
# Out:
# 1      5
# 2     35
# 3    227
# 4    374
# 5     11
# dtype: int64

# %%
print((file.isnull()).sum())
print(file.head)
# Out:
# 0      0
# 1      5
# 2     35
# 3    227
# 4    374
# 5     11
# 6      0
# 7      0
# 8      0
# dtype: int64
# <bound method NDFrame.head of       0      1     2     3      4     5      6   7  8
# 0     6  148.0  72.0  35.0    NaN  33.6  0.627  50  1
# 1     1   85.0  66.0  29.0    NaN  26.6  0.351  31  0
# 2     8  183.0  64.0   NaN    NaN  23.3  0.672  32  1
# 3     1   89.0  66.0  23.0   94.0  28.1  0.167  21  0
# 4     0  137.0  40.0  35.0  168.0  43.1  2.288  33  1
# ..   ..    ...   ...   ...    ...   ...    ...  .. ..
# 763  10  101.0  76.0  48.0  180.0  32.9  0.171  63  0
# 764   2  122.0  70.0  27.0    NaN  36.8  0.340  27  0
# 765   5  121.0  72.0  23.0  112.0  26.2  0.245  30  0
# 766   1  126.0  60.0   NaN    NaN  30.1  0.349  47  1
# 767   1   93.0  70.0  31.0    NaN  30.4  0.315  23  0
#
# [768 rows x 9 columns]>

# %%
values = file.values
file.fillna(file.mean(), inplace=True)

# %%
sls.countplot(file[8],label="outcome")
legend('no diabetis')

# %%
file.groupby(8).hist(figsize=(9, 9))
# Out:
# 8
# 0    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object
